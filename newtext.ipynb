# %%
# !apt-get update


from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [92.1 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [930 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,818 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,226 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [852 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [8,815 B]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [59.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [73.6 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [20.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,385 kB]
# Get:24 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [876 kB]
# Fetched 7,613 kB in 6s (1,270 kB/s)
# Reading package lists... Done

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b43c9068-7c7a-4ac3-b561-7bafaccb90fb" name="files[]" multiple disabled />
#      <output id="result-b43c9068-7c7a-4ac3-b561-7bafaccb90fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving eng-rus.txt to eng-rus.txt

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Za-яА-Я.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')[:2]] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)
    print(pairs)
    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 10

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s ",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):
  
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    #print(pairs)
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'deu', True)
#input_lang, output_lang, pairs = prepareData('eng', 'rus', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Trimmed to 11299 sentence pairs
# Counting words...
# Counted words:
# deu 4805
# eng 3079
# ['ich frage dich was du denkst .', 'i m asking you what you think .']

# %%
input_lang2, output_lang2, pairs2 = prepareData('eng', 'rus', True)
print(random.choice(pairs2))
# Out:
# Reading lines...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Trimmed to 22589 sentence pairs
# Counting words...
# Counted words:
# rus 8836
# eng 3812
# ['я довольно толстыи .', 'i m pudgy .']

# %%
pairs2
# Out:
# [['мне девятнадцать лет .', 'i m .'],
#  ['со мнои все в порядке .', 'i m ok .'],
#  ['у меня все хорошо .', 'i m ok .'],
#  ['я в порядке .', 'i m ok .'],
#  ['у меня все в порядке .', 'i m ok .'],
#  ['я встал .', 'i m up .'],
#  ['я встала .', 'i m up .'],
#  ['я том .', 'i m tom .'],
#  ['я плохои .', 'i m bad .'],
#  ['я плохая .', 'i m bad .'],
#  ['я толстыи .', 'i m fat .'],
#  ['я толстая .', 'i m fat .'],
#  ['я в форме .', 'i m fit .'],
#  ['меня ударили !', 'i m hit !'],
#  ['мне жарко .', 'i m hot .'],
#  ['я болен .', 'i m ill .'],
#  ['я болею .', 'i m ill .'],
#  ['я больна .', 'i m ill .'],
#  ['я сумасшедшии .', 'i m mad .'],
#  ['я злюсь .', 'i m mad .'],
#  ['я новичок .', 'i m new .'],
#  ['я новенькая .', 'i m new .'],
#  ['я старыи .', 'i m old .'],
#  ['я старая .', 'i m old .'],
#  ['мне грустно .', 'i m sad .'],
#  ['я стесняюсь .', 'i m shy .'],
#  ['я стеснительныи .', 'i m shy .'],
#  ['я стеснительная .', 'i m shy .'],
#  ['я застенчивыи .', 'i m shy .'],
#  ['я застенчивая .', 'i m shy .'],
#  ['я робкии .', 'i m shy .'],
#  ['я робкая .', 'i m shy .'],
#  ['я стеснителен .', 'i m shy .'],
#  ['я стеснительна .', 'i m shy .'],
#  ['я мокрая .', 'i m wet .'],
#  ['я мокрыи .', 'i m wet .'],
#  ['он мокрыи .', 'he s wet .'],
#  ['я старыи .', 'i am old .'],
#  ['я старая .', 'i am old .'],
#  ['я стар .', 'i am old .'],
#  ['я диджеи .', 'i m a dj .'],
#  ['я вернулся .', 'i m back .'],
#  ['это опять я .', 'i m back .'],
#  ['я вернулась .', 'i m back .'],
#  ['я лысыи .', 'i m bald .'],
#  ['я лысая .', 'i m bald .'],
#  ['я занят .', 'i m busy .'],
#  ['я занята .', 'i m busy .'],
#  ['я спокоина .', 'i m calm .'],
#  ['мне холодно .', 'i m cold .'],
#  ['я замерз .', 'i m cold .'],
#  ['я замерзла .', 'i m cold .'],
#  ['я классныи .', 'i m cool .'],
#  ['я классная .', 'i m cool .'],
#  ['я крут .', 'i m cool .'],
#  ['я клевая .', 'i m cool .'],
#  ['я глухои .', 'i m deaf .'],
#  ['я глухая .', 'i m deaf .'],
#  ['я закончил .', 'i m done .'],
#  ['меня не волнует .', 'i m easy .'],
#  ['я честныи .', 'i m fair .'],
#  ['я быстрыи .', 'i m fast .'],
#  ['я быстрая .', 'i m fast .'],
#  ['со мнои все в порядке .', 'i m fine .'],
#  ['я в порядке .', 'i m fine .'],
#  ['я свободна !', 'i m free !'],
#  ['я свободен !', 'i m free !'],
#  ['я свободна .', 'i m free .'],
#  ['я наелся .', 'i m full .'],
#  ['я сыт .', 'i m full .'],
#  ['я сыта .', 'i m full .'],
#  ['я наелась .', 'i m full .'],
#  ['я рад .', 'i m glad .'],
#  ['я рада .', 'i m glad .'],
#  ['я хорошии .', 'i m good .'],
#  ['я хорошая .', 'i m good .'],
#  ['я здесь .', 'i m here .'],
#  ['я тут .', 'i m here .'],
#  ['я под каифом .', 'i m high .'],
#  ['я дома .', 'i m home .'],
#  ['я травмирован .', 'i m hurt .'],
#  ['я травмирована .', 'i m hurt .'],
#  ['я последнии .', 'i m last .'],
#  ['я последняя .', 'i m last .'],
#  ['я опоздал .', 'i m late .'],
#  ['я опоздала .', 'i m late .'],
#  ['я опаздываю .', 'i m late .'],
#  ['я ленивыи .', 'i m lazy .'],
#  ['я лентяи .', 'i m lazy .'],
#  ['я ленивая .', 'i m lazy .'],
#  ['я заблудился .', 'i m lost .'],
#  ['я потерялся .', 'i m lost .'],
#  ['я заблудилась .', 'i m lost .'],
#  ['я потерялась .', 'i m lost .'],
#  ['я подлыи .', 'i m mean .'],
#  ['я вредныи .', 'i m mean .'],
#  ['я зловредныи .', 'i m mean .'],
#  ['я злои .', 'i m mean .'],
#  ['я злая .', 'i m mean .'],
#  ['я аккуратныи .', 'i m neat .'],
#  ['я аккуратная .', 'i m neat .'],
#  ['я следующии .', 'i m next .'],
#  ['я немои .', 'i m numb .'],
#  ['я немая .', 'i m numb .'],
#  ['у меня все хорошо .', 'i m okay .'],
#  ['я в порядке .', 'i m okay .'],
#  ['у меня все в порядке .', 'i m okay .'],
#  ['я бедная .', 'i m poor .'],
#  ['я бедныи .', 'i m poor .'],
#  ['я богат .', 'i m rich .'],
#  ['я богата .', 'i m rich .'],
#  ['я богатая .', 'i m rich .'],
#  ['я богатыи .', 'i m rich .'],
#  ['я в безопасности .', 'i m safe .'],
#  ['я болен .', 'i m sick .'],
#  ['я болею .', 'i m sick .'],
#  ['я больна .', 'i m sick .'],
#  ['я медлительныи .', 'i m slow .'],
#  ['я медленныи .', 'i m slow .'],
#  ['я медленная .', 'i m slow .'],
#  ['я медлительная .', 'i m slow .'],
#  ['я уверена .', 'i m sure .'],
#  ['я убежден .', 'i m sure .'],
#  ['я высокии .', 'i m tall .'],
#  ['я высокая .', 'i m tall .'],
#  ['я худои .', 'i m thin .'],
#  ['я опрятныи .', 'i m tidy .'],
#  ['я опрятная .', 'i m tidy .'],
#  ['я уродина .', 'i m ugly .'],
#  ['я некрасивая .', 'i m ugly .'],
#  ['я некрасивыи .', 'i m ugly .'],
#  ['я безобразен .', 'i m ugly .'],
#  ['я безобразна .', 'i m ugly .'],
#  ['мне тепло .', 'i m warm .'],
#  ['я слаб .', 'i m weak .'],
#  ['я слаба .', 'i m weak .'],
#  ['я слабыи .', 'i m weak .'],
#  ['я слабая .', 'i m weak .'],
#  ['со мнои все хорошо .', 'i m well .'],
#  ['я умныи .', 'i m wise .'],
#  ['мы в порядке .', 'we re ok .'],
#  ['он болен .', 'he is ill .'],
#  ['он болеет .', 'he is ill .'],
#  ['он диджеи .', 'he s a dj .'],
#  ['он занят .', 'he s busy .'],
#  ['он хорошии .', 'he s good .'],
#  ['он ленивыи .', 'he s lazy .'],
#  ['он мои .', 'he s mine .'],
#  ['он богатыи .', 'he s rich .'],
#  ['он богат .', 'he s rich .'],
#  ['я таец .', 'i am thai .'],
#  ['я таика .', 'i am thai .'],
#  ['мне холодно .', 'i am cold .'],
#  ['я замерз .', 'i am cold .'],
#  ['я замерзла .', 'i am cold .'],
#  ['я наелся .', 'i am full .'],
#  ['я сыт .', 'i am full .'],
#  ['я наелась .', 'i am full .'],
#  ['я хорошии .', 'i am good .'],
#  ['я хорошая .', 'i am good .'],
#  ['я заблудился .', 'i am lost .'],
#  ['я заблудилась .', 'i am lost .'],
#  ['со мнои все в порядке .', 'i am okay .'],
#  ['у меня все хорошо .', 'i am okay .'],
#  ['я в порядке .', 'i am okay .'],
#  ['у меня все в порядке .', 'i am okay .'],
#  ['я болен .', 'i am sick .'],
#  ['мне дурно .', 'i am sick .'],
#  ['я болею .', 'i am sick .'],
#  ['я больна .', 'i am sick .'],
#  ['я уверена .', 'i am sure .'],
#  ['я убежден .', 'i am sure .'],
#  ['я высокии .', 'i am tall .'],
#  ['я высокая .', 'i am tall .'],
#  ['у меня все хорошо .', 'i am well .'],
#  ['я в порядке .', 'i am well .'],
#  ['я дипломированныи бухгалтер .', 'i m a cpa .'],
#  ['я полицеиская .', 'i m a cop .'],
#  ['я фанат .', 'i m a fan .'],
#  ['я фанатка .', 'i m a fan .'],
#  ['я мужчина .', 'i m a man .'],
#  ['я человек .', 'i m a man .'],
#  ['я мужик .', 'i m a man .'],
#  ['я профи .', 'i m a pro .'],
#  ['я ветеран .', 'i m a vet .'],
#  ['я ветеринар .', 'i m a vet .'],
#  ['я жив .', 'i m alive .'],
#  ['я жива .', 'i m alive .'],
#  ['я живои .', 'i m alive .'],
#  ['я живая .', 'i m alive .'],
#  ['я один .', 'i m alone .'],
#  ['я одна .', 'i m alone .'],
#  ['я в одиночестве .', 'i m alone .'],
#  ['я зол .', 'i m angry .'],
#  ['я зла .', 'i m angry .'],
#  ['я злюсь .', 'i m angry .'],
#  ['я разозлен .', 'i m angry .'],
#  ['я разозлена .', 'i m angry .'],
#  ['я вооружен .', 'i m armed .'],
#  ['я вооружена .', 'i m armed .'],
#  ['я вооружен .', 'i m armed .'],
#  ['я проснулся .', 'i m awake .'],
#  ['я бодрствую .', 'i m awake .'],
#  ['я не сплю .', 'i m awake .'],
#  ['я проснулась .', 'i m awake .'],
#  ['я слепая .', 'i m blind .'],
#  ['я слепои .', 'i m blind .'],
#  ['я властныи .', 'i m bossy .'],
#  ['я властная .', 'i m bossy .'],
#  ['я храбрыи .', 'i m brave .'],
#  ['я храбрая .', 'i m brave .'],
#  ['я смелыи .', 'i m brave .'],
#  ['я смелая .', 'i m brave .'],
#  ['я отважныи .', 'i m brave .'],
#  ['я отважная .', 'i m brave .'],
#  ['я на нуле .', 'i m broke .'],
#  ['я на мели .', 'i m broke .'],
#  ['я чистыи .', 'i m clean .'],
#  ['я чистая .', 'i m clean .'],
#  ['я псих .', 'i m crazy .'],
#  ['я сумасшедшии .', 'i m crazy .'],
#  ['я сумасшедшая .', 'i m crazy .'],
#  ['я излечен .', 'i m cured .'],
#  ['меня вылечили .', 'i m cured .'],
#  ['я излечена .', 'i m cured .'],
#  ['у меня голова кружится .', 'i m dizzy .'],
#  ['у меня кружится голова .', 'i m dizzy .'],
#  ['я пьян .', 'i m drunk .'],
#  ['я пьяна .', 'i m drunk .'],
#  ['я пьяныи .', 'i m drunk .'],
#  ['я пьяная .', 'i m drunk .'],
#  ['я умираю .', 'i m dying .'],
#  ['я рано .', 'i m early .'],
#  ['я первыи .', 'i m first .'],
#  ['я первая .', 'i m first .'],
#  ['я придирчивыи .', 'i m fussy .'],
#  ['я придирчивая .', 'i m fussy .'],
#  ['я ухожу .', 'i m going .'],
#  ['ну я поиду .', 'i m going .'],
#  ['я иду .', 'i m going .'],
#  ['я доволен .', 'i m happy .'],
#  ['я любим .', 'i m loved .'],
#  ['я любима .', 'i m loved .'],
#  ['меня любят .', 'i m loved .'],
#  ['я преданныи .', 'i m loyal .'],
#  ['я преданная .', 'i m loyal .'],
#  ['мне везет .', 'i m lucky .'],
#  ['я везучии .', 'i m lucky .'],
#  ['я удачлив .', 'i m lucky .'],
#  ['я удачлива .', 'i m lucky .'],
#  ['вру .', 'i m lying .'],
#  ['я лежу .', 'i m lying .'],
#  ['я лгу .', 'i m lying .'],
#  ['я вру .', 'i m lying .'],
#  ['я наивныи .', 'i m naive .'],
#  ['я наивная .', 'i m naive .'],
#  ['я раздетыи .', 'i m naked .'],
#  ['я голыи .', 'i m naked .'],
#  ['я голая .', 'i m naked .'],
#  ['я нуждаюсь .', 'i m needy .'],
#  ['я в нужде .', 'i m needy .'],
#  ['я жирныи .', 'i m obese .'],
#  ['я разборчивыи .', 'i m picky .'],
#  ['я разборчивая .', 'i m picky .'],
#  ['я довольно толстыи .', 'i m pudgy .'],
#  ['я довольно толстая .', 'i m pudgy .'],
#  ['я тихии .', 'i m quiet .'],
#  ['я готова !', 'i m ready !'],
#  ['я готов !', 'i m ready !'],
#  ['я готов .', 'i m ready .'],
#  ['я готова .', 'i m ready .'],
#  ['я прав .', 'i m right .'],
#  ['я невысокая .', 'i m short .'],
#  ['я небольшого роста .', 'i m short .'],
#  ['я низкии .', 'i m short .'],
#  ['я низкая .', 'i m short .'],
#  ['я маленькии .', 'i m small .'],
#  ['я маленькая .', 'i m small .'],
#  ['я умныи .', 'i m smart .'],
#  ['я умная .', 'i m smart .'],
#  ['я трезв .', 'i m sober .'],
#  ['я трезвыи .', 'i m sober .'],
#  ['я трезвая .', 'i m sober .'],
#  ['я трезва .', 'i m sober .'],
#  ['прошу прощения .', 'i m sorry .'],
#  ['извините .', 'i m sorry .'],
#  ['я извиняюсь .', 'i m sorry .'],
#  ['извините . . .', 'i m sorry .'],
#  ['мне жаль .', 'i m sorry .'],
#  ['сожалею .', 'i m sorry .'],
#  ['сожалею !', 'i m sorry .'],
#  ['я в тупике .', 'i m stuck .'],
#  ['я напряжен .', 'i m tense .'],
#  ['я напряжена .', 'i m tense .'],
#  ['я робкии .', 'i m timid .'],
#  ['я подвыпившии .', 'i m tipsy .'],
#  ['я подвыпившая .', 'i m tipsy .'],
#  ['я навеселе .', 'i m tipsy .'],
#  ['я устал !', 'i m tired .'],
#  ['я устала !', 'i m tired .'],
#  ['я устала .', 'i m tired .'],
#  ['я крутои .', 'i m tough .'],
#  ['я крутая .', 'i m tough .'],
#  ['я расстроен .', 'i m upset .'],
#  ['я расстроена .', 'i m upset .'],
#  ['я огорчен .', 'i m upset .'],
#  ['я огорчена .', 'i m upset .'],
#  ['я неправ .', 'i m wrong .'],
#  ['я неправа .', 'i m wrong .'],
#  ['я молод .', 'i m young .'],
#  ['я молодои .', 'i m young .'],
#  ['я молодая .', 'i m young .'],
#  ['я твои .', 'i m yours .'],
#  ['я ваш .', 'i m yours .'],
#  ['я твои .', 'i m yours .'],
#  ['я твоя .', 'i m yours .'],
#  ['еи жарко .', 'she s hot .'],
#  ['нам жарко .', 'we re hot .'],
#  ['нам грустно .', 'we re sad .'],
#  ['мы застенчивы .', 'we re shy .'],
#  ['мы робкие .', 'we re shy .'],
#  ['мы застенчивые .', 'we re shy .'],
#  ['ты в порядке .', 'you re ok .'],
#  ['вы в порядке .', 'you re ok .'],
#  ['он диджеи .', 'he is a dj .'],
#  ['он занят .', 'he is busy .'],
#  ['он здесь !', 'he is here !'],
#  ['он добрыи .', 'he is kind .'],
#  ['он опаздывает .', 'he is late .'],
#  ['он ленивыи .', 'he is lazy .'],
#  ['он хорошии .', 'he is nice .'],
#  ['он славныи .', 'he is nice .'],
#  ['он беден .', 'he is poor .'],
#  ['он болен .', 'he is sick .'],
#  ['он болеет .', 'he is sick .'],
#  ['он швеицарец .', 'he s swiss .'],
#  ['он жесткии .', 'he s cruel .'],
#  ['он пьяныи .', 'he s drunk .'],
#  ['он врет .', 'he s lying .'],
#  ['он лжет .', 'he s lying .'],
#  ['он смышленыи .', 'he s smart .'],
#  ['я мужчина .', 'i am a man .'],
#  ['я человек .', 'i am a man .'],
#  ['я счастлива !', 'i am happy .'],
#  ['я человек .', 'i am human .'],
#  ['я готов .', 'i am ready .'],
#  ['я готова .', 'i am ready .'],
#  ['я прав .', 'i am right .'],
#  ['я невысокая .', 'i am short .'],
#  ['я небольшого роста .', 'i am short .'],
#  ['я низкии .', 'i am short .'],
#  ['я умныи .', 'i am smart .'],
#  ['я умная .', 'i am smart .'],
#  ['сеичас мне тридцать .', 'i m now .'],
#  ['сеичас я в порядке .', 'i m ok now .'],
#  ['я повариха .', 'i m a cook .'],
#  ['я девушка .', 'i m a girl .'],
#  ['я девочка .', 'i m a girl .'],
#  ['я герои .', 'i m a hero .'],
#  ['я героиня .', 'i m a hero .'],
#  ['я лжец .', 'i m a liar .'],
#  ['я врун .', 'i m a liar .'],
#  ['от меня один беспорядок .', 'i m a mess .'],
#  ['я монах .', 'i m a monk .'],
#  ['я монахиня .', 'i m a monk .'],
#  ['я поэт .', 'i m a poet .'],
#  ['я поэтесса .', 'i m a poet .'],
#  ['я временныи работник .', 'i m a temp .'],
#  ['я временная работница .', 'i m a temp .'],
#  ['у меня есть брат близнец .', 'i m a twin .'],
#  ['у меня есть сестра близнец .', 'i m a twin .'],
#  ['я близнец .', 'i m a twin .'],
#  ['я тряпка .', 'i m a wimp .'],
#  ['я хлюпик .', 'i m a wimp .'],
#  ['я напуган .', 'i m afraid .'],
#  ['мне страшно .', 'i m afraid .'],
#  ['я боюсь .', 'i m afraid .'],
#  ['я развеселился .', 'i m amused .'],
#  ['я развеселилась .', 'i m amused .'],
#  ['у меня анемия .', 'i m anemic .'],
#  ['я пеку .', 'i m baking .'],
#  ['мне лучше .', 'i m better .'],
#  ['я необъективен .', 'i m biased .'],
#  ['я необъективна .', 'i m biased .'],
#  ['я предвзят .', 'i m biased .'],
#  ['я умен .', 'i m bright .'],
#  ['я умна .', 'i m bright .'],
#  ['я страшно устал .', 'i m bushed .'],
#  ['я страшно устала .', 'i m bushed .'],
#  ['я покупаю .', 'i m buying .'],
#  ['я пухлыи .', 'i m chubby .'],
#  ['я пухлая .', 'i m chubby .'],
#  ['я умныи .', 'i m clever .'],
#  ['я умная .', 'i m clever .'],
#  ['я неуклюжии .', 'i m clumsy .'],
#  ['я неуклюжая .', 'i m clumsy .'],
#  ['иду .', 'i m coming .'],
#  ['я приду .', 'i m coming .'],
#  ['я иду .', 'i m coming .'],
#  ['я коварныи .', 'i m crafty .'],
#  ['я коварная .', 'i m crafty .'],
#  ['я прямои .', 'i m direct .'],
#  ['я прямая .', 'i m direct .'],
#  ['я ем .', 'i m eating .'],
#  ['я знаменит .', 'i m famous .'],
#  ['я знаменита .', 'i m famous .'],
#  ['я известен .', 'i m famous .'],
#  ['я известна .', 'i m famous .'],
#  ['я быстрее .', 'i m faster .'],
#  ['я обрюзг .', 'i m flabby .'],
#  ['я обрюзгла .', 'i m flabby .'],
#  ['я за .', 'i m for it .'],
#  ['я бережливыи .', 'i m frugal .'],
#  ['я бережливая .', 'i m frugal .'],
#  ['я жадныи .', 'i m greedy .'],
#  ['я жадная .', 'i m greedy .'],
#  ['меня пошатывает .', 'i m groggy .'],
#  ['я виновен .', 'i m guilty .'],
#  ['виноват .', 'i m guilty .'],
#  ['виновата .', 'i m guilty .'],
#  ['я виновна .', 'i m guilty .'],
#  ['я прячусь .', 'i m hiding .'],
#  ['я честныи .', 'i m honest .'],
#  ['я скромныи .', 'i m humble .'],
#  ['я скромная .', 'i m humble .'],
#  ['я есть хочу !', 'i m hungry !'],
#  ['я голодныи !', 'i m hungry !'],
#  ['я голоден !', 'i m hungry !'],
#  ['я голодная !', 'i m hungry !'],
#  ['я голодна !', 'i m hungry !'],
#  ['я хочу есть .', 'i m hungry .'],
#  ['я голодна .', 'i m hungry .'],
#  ['я голодныи .', 'i m hungry .'],
#  ['я голодная .', 'i m hungry .'],
#  ['я невосприимчив .', 'i m immune .'],
#  ['я невосприимчива .', 'i m immune .'],
#  ['я в кровати .', 'i m in bed .'],
#  ['я в постели .', 'i m in bed .'],
#  ['я внутри .', 'i m inside .'],
#  ['шучу .', 'i m joking .'],
#  ['я пьяныи .', 'i m loaded .'],
#  ['я пьяная .', 'i m loaded .'],
#  ['я бухои .', 'i m loaded .'],
#  ['я бухая .', 'i m loaded .'],
#  ['я одинока .', 'i m lonely .'],
#  ['я проигрываю .', 'i m losing .'],
#  ['я взрослыи .', 'i m mature .'],
#  ['я взрослая .', 'i m mature .'],
#  ['я переезжаю .', 'i m moving .'],
#  ['я нормальныи .', 'i m normal .'],
#  ['я нормальная .', 'i m normal .'],
#  ['я не в порядке .', 'i m not ok .'],
#  ['я не участвую .', 'i m not in .'],
#  ['плачу я .', 'i m paying .'],
#  ['я плачу .', 'i m paying .'],
#  ['я отдохнул .', 'i m rested .'],
#  ['я отдохнула .', 'i m rested .'],
#  ['я опустошен .', 'i m ruined .'],
#  ['я опустошена .', 'i m ruined .'],
#  ['я напуган .', 'i m scared .'],
#  ['я напугана .', 'i m scared .'],
#  ['мне страшно .', 'i m scared .'],
#  ['я потрясен .', 'i m shaken .'],
#  ['я потрясена .', 'i m shaken .'],
#  ['я тощии .', 'i m skinny .'],
#  ['я тощая .', 'i m skinny .'],
#  ['я хочу спать !', 'i m sleepy !'],
#  ['я спать хочу !', 'i m sleepy !'],
#  ['спать хочу !', 'i m sleepy !'],
#  ['спать хочется !', 'i m sleepy !'],
#  ['я сонныи .', 'i m sleepy .'],
#  ['мне хочется спать .', 'i m sleepy .'],
#  ['я сонная .', 'i m sleepy .'],
#  ['я подлыи .', 'i m sneaky .'],
#  ['я такая толстая .', 'i m so fat .'],
#  ['я такои толстыи .', 'i m so fat .'],
#  ['я так взбешен .', 'i m so mad .'],
#  ['я так взбешена .', 'i m so mad .'],
#  ['меня можно выжимать .', 'i m soaked .'],
#  ['я твердыи .', 'i m stable .'],
#  ['я твердая .', 'i m stable .'],
#  ['я строг .', 'i m strict .'],
#  ['я сильная .', 'i m strong .'],
#  ['я глупыи .', 'i m stupid .'],
#  ['я глупая .', 'i m stupid .'],
#  ['мне тридцать лет .', 'i m thirty .'],
#  ['мне тридцать .', 'i m thirty .'],
#  ['я пытаюсь .', 'i m trying .'],
#  ['я стараюсь .', 'i m trying .'],
#  ['мне двенадцать .', 'i m twelve .'],
#  ['я невредим .', 'i m unhurt .'],
#  ['я невредима .', 'i m unhurt .'],
#  ['я не уверена .', 'i m unsure .'],
#  ['я не уверен .', 'i m unsure .'],
#  ['я неопрятныи .', 'i m untidy .'],
#  ['я неопрятная .', 'i m untidy .'],
#  ['мне нехорошо .', 'i m unwell .'],
#  ['я изможден .', 'i m wasted .'],
#  ['я измождена .', 'i m wasted .'],
#  ['она стара .', 'she is old .'],
#  ['она старая .', 'she is old .'],
#  ['она занята .', 'she s busy .'],
#  ['она моя .', 'she s mine .'],
#  ['она хорошая .', 'she s nice .'],
#  ['она милая .', 'she s nice .'],
#  ['мы люди .', 'we are men .'],
#  ['мы мужчины .', 'we are men .'],
#  ['мы вернулись .', 'we re back .'],
#  ['мы мальчики .', 'we re boys .'],
#  ['мы заняты .', 'we re busy .'],
#  ['мы спокоины .', 'we re calm .'],
#  ['нам холодно .', 'we re cold .'],
#  ['мы крутые .', 'we re cool .'],
#  ['мы классные .', 'we re cool .'],
#  ['мы закончили .', 'we re done .'],
#  ['мы квиты .', 'we re even .'],
#  ['мы честны .', 'we re fair .'],
#  ['мы справедливы .', 'we re fair .'],
#  ['мы в порядке .', 'we re fine .'],
#  ['у нас все отлично .', 'we re fine .'],
#  ['у нас все хорошо .', 'we re fine .'],
#  ['мы свободны !', 'we re free !'],
#  ['мы свободны .', 'we re free .'],
#  ['мы наелись .', 'we re full .'],
#  ['мы здесь .', 'we re here .'],
#  ['мы тут .', 'we re here .'],
#  ['мы дома .', 'we re home .'],
#  ['мы опаздываем .', 'we re late .'],
#  ['мы ленивые .', 'we re lazy .'],
#  ['мы потерялись .', 'we re lost .'],
#  ['мы заблудились .', 'we re lost .'],
#  ['мы бедные .', 'we re poor .'],
#  ['мы бедны .', 'we re poor .'],
#  ['мы богаты .', 'we re rich .'],
#  ['мы богатые .', 'we re rich .'],
#  ['мы в безопасности .', 'we re safe .'],
#  ['мы больны .', 'we re sick .'],
#  ['мы болеем .', 'we re sick .'],
#  ['мы слабы .', 'we re weak .'],
#  ['ты плохои .', 'you re bad .'],
#  ['ты забавныи .', 'you re fun .'],
#  ['ты забавная .', 'you re fun .'],
#  ['вы забавныи .', 'you re fun .'],
#  ['вы забавная .', 'you re fun .'],
#  ['вы забавные .', 'you re fun .'],
#  ['ты странныи .', 'you re odd .'],
#  ['вы странные .', 'you re odd .'],
#  ['ты странная .', 'you re odd .'],
#  ['вы странныи .', 'you re odd .'],
#  ['вы странная .', 'you re odd .'],
#  ['ты старая .', 'you re old .'],
#  ['ты старыи .', 'you re old .'],
#  ['вы старые .', 'you re old .'],
#  ['вы старая .', 'you re old .'],
#  ['вы старыи .', 'you re old .'],
#  ['вы грустныи .', 'you re sad .'],
#  ['вы грустная .', 'you re sad .'],
#  ['ты грустныи .', 'you re sad .'],
#  ['ты грустная .', 'you re sad .'],
#  ['вам грустно .', 'you re sad .'],
#  ['тебе грустно .', 'you re sad .'],
#  ['ты стеснительныи .', 'you re shy .'],
#  ['вы застенчивыи .', 'you re shy .'],
#  ['вы застенчивая .', 'you re shy .'],
#  ['ты застенчивыи .', 'you re shy .'],
#  ['ты застенчивая .', 'you re shy .'],
#  ['он одинок .', 'he is alone .'],
#  ['он один .', 'he is alone .'],
#  ['он безумен .', 'he is crazy .'],
#  ['он сумасшедшии .', 'he is crazy .'],
#  ['он псих .', 'he is crazy .'],
#  ['ему восемь .', 'he is eight .'],
#  ['он счастлив .', 'he is happy .'],
#  ['он ненавистныи .', 'he is hated .'],
#  ['он врет .', 'he is lying .'],
#  ['он лжет .', 'he is lying .'],
#  ['он противныи .', 'he is nasty .'],
#  ['он устал .', 'he is tired .'],
#  ['он молод .', 'he is young .'],
#  ['он молодои .', 'he is young .'],
#  ['он мудак .', 'he s a jerk .'],
#  ['он лжец .', 'he s a liar .'],
#  ['он лгун .', 'he s a liar .'],
#  ['он врун .', 'he s a liar .'],
#  ['он ботаник .', 'he s a nerd .'],
#  ['он задрот .', 'he s a nerd .'],
#  ['он неряха .', 'he s a slob .'],
#  ['он разгильдяи .', 'he s a slob .'],
#  ['он спит .', 'he s asleep .'],
#  ['он едет .', 'he s coming .'],
#  ['он идет .', 'he s coming .'],
#  ['он плачет .', 'he s crying .'],
#  ['он притворяется .', 'he s faking .'],
#  ['он симулирует .', 'he s faking .'],
#  ['он мои ровесник .', 'he s my age .'],
#  ['его нет .', 'he s not in .'],
#  ['он худои .', 'he s skinny .'],
#  ['он тощии .', 'he s skinny .'],
#  ['он худощавыи .', 'he s skinny .'],
#  ['он поджарыи .', 'he s skinny .'],
#  ['он сильныи .', 'he s strong .'],
#  ['он тупои .', 'he s stupid .'],
#  ['он тормоз .', 'he s stupid .'],
#  ['он глупыи .', 'he s stupid .'],
#  ['он олень .', 'he s stupid .'],
#  ['он тупои как олень .', 'he s stupid .'],
#  ['он бестолковыи .', 'he s stupid .'],
#  ['он безмозглыи .', 'he s stupid .'],
#  ['он бестолочь .', 'he s stupid .'],
#  ['он безголовыи .', 'he s stupid .'],
#  ['он непонятливыи .', 'he s stupid .'],
#  ['он недалекии .', 'he s stupid .'],
#  ['он ограниченныи .', 'he s stupid .'],
#  ['он слабоумныи .', 'he s stupid .'],
#  ['он скудоумныи .', 'he s stupid .'],
#  ['он глуп как бревно .', 'he s stupid .'],
#  ['он тупои как пробка .', 'he s stupid .'],
#  ['он тормознутыи .', 'he s stupid .'],
#  ['он неумныи .', 'he s stupid .'],
#  ['он придурковатыи .', 'he s stupid .'],
#  ['он тупоголовыи .', 'he s stupid .'],
#  ['он тупорылыи .', 'he s stupid .'],
#  ['он узколобыи .', 'he s stupid .'],
#  ['он малоумныи .', 'he s stupid .'],
#  ['он баран .', 'he s stupid .'],
#  ['он чудик .', 'he s stupid .'],
#  ['я монах .', 'i am a monk .'],
#  ['я близнец .', 'i am a twin .'],
#  ['я лучше .', 'i am better .'],
#  ['мне лучше .', 'i am better .'],
#  ['иду .', 'i am coming .'],
#  ['я клюю носом .', 'i am dozing .'],
#  ['я дремлю .', 'i am dozing .'],
#  ['я в сети .', 'i am online .'],
#  ['я выше .', 'i am taller .'],
#  ['мне тоже семнадцать лет .', 'i m too .'],
#  ['мне тоже семнадцать .', 'i m too .'],
#  ['я пекарь .', 'i m a baker .'],
#  ['я боксер .', 'i m a boxer .'],
#  ['я ребенок .', 'i m a child .'],
#  ['я сторож .', 'i m a guard .'],
#  ['я недотепа .', 'i m a klutz .'],
#  ['я одиночка .', 'i m a loner .'],
#  ['я неудачник .', 'i m a loser .'],
#  ['я неудачница .', 'i m a loser .'],
#  ['я лузер .', 'i m a loser .'],
#  ['я бедолага .', 'i m a loser .'],
#  ['я горемыка .', 'i m a loser .'],
#  ['я медик .', 'i m a medic .'],
#  ['я несовершеннолетнии .', 'i m a minor .'],
#  ['я несовершеннолетняя .', 'i m a minor .'],
#  ['я медсестра .', 'i m a nurse .'],
#  ['я медбрат .', 'i m a nurse .'],
#  ['я пилот .', 'i m a pilot .'],
#  ['я летчик .', 'i m a pilot .'],
#  ['я бунтарь .', 'i m a rebel .'],
#  ['я мятежник .', 'i m a rebel .'],
#  ['я бунтарка .', 'i m a rebel .'],
#  ['я мятежница .', 'i m a rebel .'],
#  ['я веган .', 'i m a vegan .'],
#  ['я женщина .', 'i m a woman .'],
#  ['меня усыновили .', 'i m adopted .'],
#  ['меня удочерили .', 'i m adopted .'],
#  ['у меня все готово .', 'i m all set .'],
#  ['мне стыдно .', 'i m ashamed .'],
#  ['я дома .', 'i m at home .'],
#  ['я на работе .', 'i m at work .'],
#  ['я озадачен .', 'i m baffled .'],
#  ['я озадачена .', 'i m baffled .'],
#  ['у меня биполярное расстроиство .', 'i m bipolar .'],
#  ['я счастливыи .', 'i m blessed .'],
#  ['я счастливая .', 'i m blessed .'],
#  ['я осторожен .', 'i m careful .'],
#  ['я осторожна .', 'i m careful .'],
#  ['я осторожныи .', 'i m careful .'],
#  ['я осторожная .', 'i m careful .'],
#  ['я убежден .', 'i m certain .'],
#  ['я трус .', 'i m chicken .'],
#  ['я трусиха .', 'i m chicken .'],
#  ['я готовлю .', 'i m cooking .'],
#  ['я прав .', 'i m correct .'],
#  ['мне любопытно .', 'i m curious .'],
#  ['я танцую .', 'i m dancing .'],
#  ['я на диете .', 'i m dieting .'],
#  ['я сижу на диете .', 'i m dieting .'],
#  ['я за рулем .', 'i m driving .'],
#  ['я веду .', 'i m driving .'],
#  ['я за рулем .', 'i m driving .'],
#  ['я помолвлена .', 'i m engaged .'],
#  ['я возбуждена .', 'i m excited .'],
#  ['я падаю .', 'i m falling .'],
#  ['я соблюдаю пост .', 'i m fasting .'],
#  ['я придирчивыи .', 'i m finicky .'],
#  ['я придирчивая .', 'i m finicky .'],
#  ['я безумен .', 'i m frantic .'],
#  ['я безумна .', 'i m frantic .'],
#  ['я взбешен .', 'i m furious .'],
#  ['я взбешена .', 'i m furious .'],
#  ['я в ярости .', 'i m furious .'],
#  ['я в бешенстве .', 'i m furious .'],
#  ['я взбешен .', 'i m furious .'],
#  ['я здоров .', 'i m healthy .'],
#  ['я здорова .', 'i m healthy .'],
#  ['я деятельныи .', 'i m humming .'],
#  ['я деятельная .', 'i m humming .'],
#  ['я здесь .', 'i m in here .'],
#  ['я тут .', 'i m in here .'],
#  ['я в тюрьме .', 'i m in jail .'],
#  ['я влюблен .', 'i m in love .'],
#  ['я влюблена .', 'i m in love .'],
#  ['я влюблен .', 'i m in love .'],
#  ['мне везет .', 'i m in luck .'],
#  ['я испытываю боль .', 'i m in pain .'],
#  ['я ревнив .', 'i m jealous .'],
#  ['я ревную .', 'i m jealous .'],
#  ['я завидую .', 'i m jealous .'],
#  ['я ревнивыи .', 'i m jealous .'],
#  ['я ревнивая .', 'i m jealous .'],
#  ['я нервныи .', 'i m jittery .'],
#  ['я нервная .', 'i m jittery .'],
#  ['шучу .', 'i m kidding .'],
#  ['я ухожу .', 'i m leaving .'],
#  ['я уезжаю .', 'i m leaving .'],
#  ['я замужем .', 'i m married .'],
#  ['я нервничаю .', 'i m nervous .'],
#  ['я безразличен .', 'i m neutral .'],
#  ['я безразлична .', 'i m neutral .'],
#  ['я не дура .', 'i m no fool .'],
#  ['я не герои .', 'i m no hero .'],
#  ['я вовсе не герои .', 'i m no hero .'],
#  ['я не героиня .', 'i m no hero .'],
#  ['я не лжец .', 'i m no liar .'],
#  ['я не лгунья .', 'i m no liar .'],
#  ['я не том .', 'i m not tom .'],
#  ['я не толстая !', 'i m not fat .'],
#  ['я не толстыи .', 'i m not fat .'],
#  ['я не толстая .', 'i m not fat .'],
#  ['я не безумен .', 'i m not mad .'],
#  ['я не старыи .', 'i m not old .'],
#  ['я не старая .', 'i m not old .'],
#  ['я не грустныи .', 'i m not sad .'],
#  ['мне не грустно .', 'i m not sad .'],
#  ['я не грустная .', 'i m not sad .'],
#  ['я не стеснительныи .', 'i m not shy .'],
#  ['я не стеснительная .', 'i m not shy .'],
#  ['я не застенчивыи .', 'i m not shy .'],
#  ['я не застенчивая .', 'i m not shy .'],
#  ['я не робкии .', 'i m not shy .'],
#  ['я не робкая .', 'i m not shy .'],
#  ['я не ты .', 'i m not you .'],
#  ['я на дежурстве .', 'i m on duty .'],
#  ['я вовремя .', 'i m on time .'],
#  ['я выше этого .', 'i m over it .'],
#  ['я пакую вещи .', 'i m packing .'],
#  ['я терпелив .', 'i m patient .'],
#  ['я терпелива .', 'i m patient .'],
#  ['я терпеливыи .', 'i m patient .'],
#  ['я терпеливая .', 'i m patient .'],
#  ['я доволен .', 'i m pleased .'],
#  ['я довольна .', 'i m pleased .'],
#  ['я популярен .', 'i m popular .'],
#  ['я популярна .', 'i m popular .'],
#  ['я благоразумныи .', 'i m prudent .'],
#  ['я предусмотрительныи .', 'i m prudent .'],
#  ['я благоразумен .', 'i m prudent .'],
#  ['я благоразумна .', 'i m prudent .'],
#  ['я балдею .', 'i m psyched .'],
#  ['я в замешательстве .', 'i m puzzled .'],
#  ['я озадачен .', 'i m puzzled .'],
#  ['я озадачена .', 'i m puzzled .'],
#  ['я читаю .', 'i m reading .'],
#  ['я спокоина .', 'i m relaxed .'],
#  ['я расслаблен .', 'i m relaxed .'],
#  ['я расслаблена .', 'i m relaxed .'],
#  ['я отдохну .', 'i m resting .'],
#  ['я отдыхаю .', 'i m resting .'],
#  ['я вышел на пенсию .', 'i m retired .'],
#  ['я пенсионер .', 'i m retired .'],
#  ['я пенсионерка .', 'i m retired .'],
#  ['я на пенсии .', 'i m retired .'],
#  ['я в отставке .', 'i m retired .'],
#  ['я вышла на пенсию .', 'i m retired .'],
#  ['теперь мне грустно .', 'i m sad now .'],
#  ['я эгоист .', 'i m selfish .'],
#  ['я эгоистка .', 'i m selfish .'],
#  ['я эгоистичен .', 'i m selfish .'],
#  ['я эгоистична .', 'i m selfish .'],
#  ['я бреюсь .', 'i m shaving .'],
#  ['я потрясен .', 'i m shocked .'],
#  ['я в шоке .', 'i m shocked .'],
#  ['я шокирован .', 'i m shocked .'],
#  ['я шокирована .', 'i m shocked .'],
#  ['я потрясена .', 'i m shocked .'],
#  ['я искренне .', 'i m sincere .'],
#  ['я в стельку .', 'i m sloshed .'],
#  ['я в дымину .', 'i m smashed .'],
#  ['мне так холодно .', 'i m so cold .'],
#  ['я так рад .', 'i m so glad .'],
#  ['я так рада .', 'i m so glad .'],
#  ['я особенныи .', 'i m special .'],
#  ['умираю с голоду .', 'i m starved .'],
#  ['я остаюсь .', 'i m staying .'],
#  ['я невероятно устал .', 'i m stuffed .'],
#  ['я невероятно устала .', 'i m stuffed .'],
#  ['у меня большие проблемы .', 'i m stuffed .'],
#  ['я объелся .', 'i m stuffed .'],
#  ['я объелась .', 'i m stuffed .'],
#  ['я в тупике .', 'i m stumped .'],
#  ['я ошеломлен .', 'i m stunned .'],
#  ['я потрясен .', 'i m stunned .'],
#  ['я ошеломлена .', 'i m stunned .'],
#  ['я ошеломлен .', 'i m stunned .'],
#  ['я разговариваю .', 'i m talking .'],
#  ['я говорю .', 'i m talking .'],
#  ['я дразнюсь .', 'i m teasing .'],
#  ['я главныи администратор .', 'i m the ceo .'],
#  ['я это закон .', 'i m the law .'],
#  ['мне хочется пить .', 'i m thirsty .'],
#  ['я хочу пить .', 'i m thirsty .'],
#  ['у меня жажда .', 'i m thirsty .'],
#  ['пить хочется .', 'i m thirsty .'],
#  ['я все .', 'i m through .'],
#  ['я слишком толстыи .', 'i m too fat .'],
#  ['я тронут .', 'i m touched .'],
#  ['я тронута .', 'i m touched .'],
#  ['я в ловушке .', 'i m trapped .'],
#  ['я безоружен .', 'i m unarmed .'],
#  ['я не вооружена .', 'i m unarmed .'],
#  ['я безоружна .', 'i m unarmed .'],
#  ['я не вооружен .', 'i m unarmed .'],
#  ['я несчастна .', 'i m unhappy .'],
#  ['я несчастен .', 'i m unhappy .'],
#  ['я несчастлива .', 'i m unhappy .'],
#  ['я несчастлив .', 'i m unhappy .'],
#  ['мне не везет .', 'i m unlucky .'],
#  ['я неудачлив .', 'i m unlucky .'],
#  ['я невезучии .', 'i m unlucky .'],
#  ['я невезучая .', 'i m unlucky .'],
#  ['я со странностями .', 'i m unusual .'],
#  ['я тут наверху .', 'i m up here .'],
#  ['я следующии .', 'i m up next .'],
#  ['я следующая .', 'i m up next .'],
#  ['я бесполезен .', 'i m useless .'],
#  ['я бесполезна .', 'i m useless .'],
#  ['я бесполезныи .', 'i m useless .'],
#  ['я бесполезная .', 'i m useless .'],
#  ['я никчемен .', 'i m useless .'],
#  ['я никчемныи .', 'i m useless .'],
#  ['я жду .', 'i m waiting .'],
#  ['жду .', 'i m waiting .'],
#  ['я богат .', 'i m wealthy .'],
#  ['я богата .', 'i m wealthy .'],
#  ['я выигрываю .', 'i m winning .'],
#  ['я побеждаю .', 'i m winning .'],
#  ['я работаю .', 'i m working .'],
#  ['я беспокоюсь .', 'i m worried .'],
#  ['я волнуюсь .', 'i m worried .'],
#  ['я обеспокоена .', 'i m worried .'],
#  ['я обеспокоен .', 'i m worried .'],
#  ['я ранена .', 'i m wounded .'],
#  ['я ранен .', 'i m wounded .'],
#  ['она умерла .', 'she is dead .'],
#  ['она мертва .', 'she is dead .'],
#  ['она добрая .', 'she is kind .'],
#  ['она опаздывает .', 'she is late .'],
#  ['она ленивая .', 'she is lazy .'],
#  ['она хорошая .', 'she is nice .'],
#  ['она славная .', 'she is nice .'],
#  ['это сука .', 'she s a dog .'],
#  ['она карга .', 'she s a dog .'],
#  ['она уродина .', 'she s a dog .'],
#  ['она собака .', 'she s a dog .'],
#  ['она сумасшедшая .', 'she s crazy .'],
#  ['она застенчивая .', 'she s timid .'],
#  ['они плохие .', 'they re bad .'],
#  ['они толстые .', 'they re fat .'],
#  ['они новые .', 'they re new .'],
#  ['они старые .', 'they re old .'],
#  ['они красные .', 'they re red .'],
#  ['они рыжие .', 'they re red .'],
#  ['мы свободны !', 'we are free !'],
#  ['мы здесь .', 'we are here .'],
#  ['мы больны .', 'we are sick .'],
#  ['мы одни .', 'we re alone .'],
#  ['мы вооружены .', 'we re armed .'],
#  ['мы не спим .', 'we re awake .'],
#  ['мы бодрствуем .', 'we re awake .'],
#  ['нам скучно .', 'we re bored .'],
#  ['нам надоело .', 'we re bored .'],
#  ['мы чисты .', 'we re clean .'],
#  ['мы сумасшедшие .', 'we re crazy .'],
#  ['мы умираем .', 'we re dying .'],
#  ['мы рано .', 'we re early .'],
#  ['мы идем .', 'we re going .'],
#  ['мы готовы .', 'we re ready .'],
#  ['мы правы .', 'we re right .'],
#  ['мы спасены .', 'we re saved .'],
#  ['мы умны .', 'we re smart .'],
#  ['мы сожалеем .', 'we re sorry .'],
#  ['нам жаль .', 'we re sorry .'],
#  ['мы застряли .', 'we re stuck .'],
#  ['мы робкие .', 'we re timid .'],
#  ['мы застенчивые .', 'we re timid .'],
#  ['мы устали .', 'we re tired .'],
#  ['мы близнецы .', 'we re twins .'],
#  ['мы расстроены .', 'we re upset .'],
#  ['мы огорчены .', 'we re upset .'],
#  ['мы юны .', 'we re young .'],
#  ['мы молоды .', 'we re young .'],
#  ['мы молодые .', 'we re young .'],
#  ['мы юные .', 'we re young .'],
#  ['ты большои .', 'you are big .'],
#  ['ты большая .', 'you are big .'],
#  ['вы большие .', 'you are big .'],
#  ['ты вернулся .', 'you re back .'],
#  ['вы вернулись .', 'you re back .'],
#  ['ты вернулась .', 'you re back .'],
#  ['ты прикольныи .', 'you re cool .'],
#  ['ты милыи .', 'you re cute .'],
#  ['ты симпатичныи .', 'you re cute .'],
#  ['ты симпатичная .', 'you re cute .'],
#  ['вы симпатичныи .', 'you re cute .'],
#  ['вы симпатичная .', 'you re cute .'],
#  ['вы симпатичные .', 'you re cute .'],
#  ['ты честен .', 'you re fair .'],
#  ['ты честныи .', 'you re fair .'],
#  ['ты справедливыи .', 'you re fair .'],
#  ['ты справедливая .', 'you re fair .'],
#  ['вы справедливы .', 'you re fair .'],
#  ['вы свободны .', 'you re free .'],
#  ['ты свободен .', 'you re free .'],
#  ['ты свободна .', 'you re free .'],
#  ['ты хорошии .', 'you re good .'],
#  ['ты хорошая .', 'you re good .'],
#  ['вы хорошие .', 'you re good .'],
#  ['ты здесь .', 'you re here .'],
#  ['вы здесь .', 'you re here .'],
#  ['вы опоздали .', 'you re late .'],
#  ['ты опоздал .', 'you re late .'],
#  ['ты опоздала .', 'you re late .'],
#  ['ты ленивыи .', 'you re lazy .'],
#  ['ты ленивая .', 'you re lazy .'],
#  ['вы ленивые .', 'you re lazy .'],
#  ['вы ленивыи .', 'you re lazy .'],
#  ['вы ленивая .', 'you re lazy .'],
#  ['ты заблудился .', 'you re lost .'],
#  ['вы заблудились .', 'you re lost .'],
#  ['вы злая .', 'you re mean .'],
#  ['вы злои .', 'you re mean .'],
#  ['ты злая .', 'you re mean .'],
#  ['ты злои .', 'you re mean .'],
#  ['ты мои .', 'you re mine .'],
#  ['ты моя .', 'you re mine .'],
#  ['вы мои .', 'you re mine .'],
#  ['вы мои .', 'you re mine .'],
#  ['вы моя .', 'you re mine .'],
#  ['ты следующии .', 'you re next .'],
#  ['вы следующии .', 'you re next .'],
#  ['ты следующая .', 'you re next .'],
#  ['вы следующая .', 'you re next .'],
#  ['вы следующие .', 'you re next .'],
#  ['ты чокнутыи !', 'you re nuts !'],
#  ['ты чокнутая !', 'you re nuts !'],
#  ['ты беден .', 'you re poor .'],
#  ['вы бедны .', 'you re poor .'],
#  ['ты богатая .', 'you re rich .'],
#  ['вы богатые .', 'you re rich .'],
#  ['вы богаты .', 'you re rich .'],
#  ['вы богатыи .', 'you re rich .'],
#  ['вы богатая .', 'you re rich .'],
#  ['ты богатыи .', 'you re rich .'],
#  ['ты богат .', 'you re rich .'],
#  ['ты богата .', 'you re rich .'],
#  ['вы грубы .', 'you re rude .'],
#  ['ты груб .', 'you re rude .'],
#  ['ты грубыи .', 'you re rude .'],
#  ['ты груба .', 'you re rude .'],
#  ['ты грубая .', 'you re rude .'],
#  ['вы грубые .', 'you re rude .'],
#  ['ты в безопасности .', 'you re safe .'],
#  ['вы в безопасности .', 'you re safe .'],
#  ['ты мерзавец .', 'you re scum .'],
#  ['вы мерзавец .', 'you re scum .'],
#  ['ты подлец .', 'you re scum .'],
#  ['вы подлец .', 'you re scum .'],
#  ['ты больнои !', 'you re sick !'],
#  ['ты болен !', 'you re sick !'],
#  ['ты болен .', 'you re sick .'],
#  ['ты больна .', 'you re sick .'],
#  ['вы больны .', 'you re sick .'],
#  ['ты худои .', 'you re thin .'],
#  ['ты худая .', 'you re thin .'],
#  ['вы худои .', 'you re thin .'],
#  ['вы худая .', 'you re thin .'],
#  ['вы худые .', 'you re thin .'],
#  ['ты опрятныи .', 'you re tidy .'],
#  ['ты уродлив .', 'you re ugly .'],
#  ['ты некрасивыи .', 'you re ugly .'],
#  ['ты некрасивая .', 'you re ugly .'],
#  ['вы некрасивы .', 'you re ugly .'],
#  ...]

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)
        
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)


import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence,  max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 75000, print_every=5000)
# Out:
# 2m 13s (- 31m 3s) (5000 6%) 3.0519
# 4m 20s (- 28m 15s) (10000 13%) 2.4998
# 6m 28s (- 25m 54s) (15000 20%) 2.1782
# 8m 35s (- 23m 37s) (20000 26%) 1.9398
# 10m 44s (- 21m 28s) (25000 33%) 1.7168
# 12m 53s (- 19m 20s) (30000 40%) 1.5419
# 15m 2s (- 17m 11s) (35000 46%) 1.4195
# 17m 10s (- 15m 1s) (40000 53%) 1.2923
# 19m 19s (- 12m 52s) (45000 60%) 1.1790
# 21m 26s (- 10m 43s) (50000 66%) 1.0916
# 23m 34s (- 8m 34s) (55000 73%) 1.0193
# 25m 42s (- 6m 25s) (60000 80%) 0.9036
# 27m 50s (- 4m 16s) (65000 86%) 0.8734
# 29m 58s (- 2m 8s) (70000 93%) 0.7976
# 32m 8s (- 0m 0s) (75000 100%) 0.7522

# %%
hidden_size = 256
encoder2 = EncoderRNN(input_lang2.n_words, hidden_size).to(device)
attn_decoder2 = AttnDecoderRNN(hidden_size, output_lang2.n_words, dropout_p=0.1).to(device)

trainIters(encoder2, attn_decoder2, 75000, print_every=5000)
# Out:
# 2m 19s (- 32m 28s) (5000 6%) 3.0759
# 4m 34s (- 29m 42s) (10000 13%) 2.5215
# 6m 49s (- 27m 17s) (15000 20%) 2.2093
# 9m 4s (- 24m 56s) (20000 26%) 1.9312
# 11m 19s (- 22m 38s) (25000 33%) 1.7681
# 13m 38s (- 20m 27s) (30000 40%) 1.5882
# 15m 57s (- 18m 14s) (35000 46%) 1.4408
# 18m 16s (- 15m 59s) (40000 53%) 1.3119
# 20m 36s (- 13m 44s) (45000 60%) 1.2003
# 22m 55s (- 11m 27s) (50000 66%) 1.1333
# 25m 12s (- 9m 9s) (55000 73%) 1.0260
# 27m 30s (- 6m 52s) (60000 80%) 0.9529
# 29m 48s (- 4m 35s) (65000 86%) 0.8916
# 32m 5s (- 2m 17s) (70000 93%) 0.8256
# 34m 22s (- 0m 0s) (75000 100%) 0.7772

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > du zahlst nun zur elite .
# = you re now among the elite .
# < you re now the the . <EOS>
#
# > sie sind fur deinen plan .
# = they are in favor of your plan .
# < they are in favor of your plan . <EOS>
#
# > es freut mich dass ich helfen konnte .
# = i m glad i could be of help .
# < i m happy i could help . <EOS>
#
# > fur den unfall konnt ihr nichts .
# = you are not to blame for the accident .
# < you are not to blame for the accident . <EOS>
#
# > du gibst nicht auf oder ?
# = you re not giving up are you ?
# < you re not giving up are you ? <EOS>
#
# > du bist sehr beschaftigt .
# = you re very busy .
# < you re very busy . <EOS>
#
# > ich bin jahre alt .
# = i m years old .
# < i m twelve . <EOS>
#
# > diese schuhe ziehe ich nie wieder an !
# = i m never wearing these shoes again .
# < you re never wearing these shoes again . <EOS>
#
# > du bist nicht sehr glucklich oder ?
# = you aren t very happy are you ?
# < you re not very happy are you ? <EOS>
#
# > ich bin ganz ohr .
# = i m all ears .
# < i m all ears . <EOS>

# %%
def evaluateSeq(input_sentence):
    output_words, attentions2 = evaluate(
        encoder2, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
